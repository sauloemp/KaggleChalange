# %% [markdown]
# <a href="https://colab.research.google.com/github/skylex141/KaggleChalange/blob/master/Titanic_Kaggle_Chalange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio Titanic Kaggle

# %% [markdown]
# ## Pacotes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Datasets de teste e treinamento

# %%
x_test = pd.read_csv('test.csv')
x_train = pd.read_csv('train.csv')
y_train = pd.read_csv('train.csv'

# %%
x_train.head() #Cabeçalho de Teste
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dfTreinamento.head() #Cabeçalho de treinamentos
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfSobrevivente.head() #Cabeçalho dos Sobreviventes
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ## Analises de Dados

# %%
dfTreinamento.corr() #Correlação dos dados de treinamento
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.matshow(dfTreinamento.corr()) #Matriz de Correlação dos dados de treinamento

# %%
dfTreinamento.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(4) 
# Matriz de Correlação dos dados de treinamento com números
# Não há correlações significante nos dados de sobrevivntes
# Out:
# <style  type="text/css" >
#     #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col1 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col2 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col3 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col4 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col5 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_9f146f9e_802f_11ea_9699_5cc9d3817d84row0_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
# ...

# %%
dfSobrevivente.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dfSobrevivente['Sex'].value_counts().plot(kind='pie', autopct='%.2f%%')
plt.axis('equal'); #A maioria dos dados de sobreviventes foram mulheres

# %%
sns.factorplot('Pclass', 'Survived', data=dfTreinamento)

# %%
DfAge = dfTreinamento['Age'].replace('NaN', None).dropna().astype(int)
sns.distplot(DfAge) 
#sns.distplot(DfAge, kde=False)
# Out:
# C:\Users\Saulo Eduardo\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
